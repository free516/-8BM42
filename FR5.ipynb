# %%
# !pip install swig
# !pip install "gymnasium[box2d]"
# !pip install matplotlib networkx imageio

import gymnasium as gym
import numpy as np
import matplotlib.pyplot as plt
import pickle
import os
import random
from copy import deepcopy
import imageio.v2 as imageio
import networkx as nx
from IPython.display import display, Image

# ----------------------------- #
# 超参数配置
# ----------------------------- #
INPUT_SIZE = 8
OUTPUT_SIZE = 4
HIDDEN_SIZE = 16
MODULE_SIZE = 4
POP_SIZE = 30
GENERATIONS = 150
EPISODES_PER_NETWORK = 5
MUTATION_RATE = 0.15
ELITE_RATIO = 0.2
OUTPUT_MUTATION_STRENGTH = 0.02


# ----------------------------- #
# 激活函数
# ----------------------------- #
def relu(x):
    return np.maximum(0, x)

def softmax(x):
    e_x = np.exp(x - np.max(x))
    return e_x / e_x.sum()

# ----------------------------- #
# 基因组定义
# ----------------------------- #
class NeuronGenome:
    def __init__(self, input_size):
        self.weights = np.random.randn(input_size)
        self.bias = np.random.randn()

    def mutate(self):
        if np.random.rand() < MUTATION_RATE:
            self.weights += np.random.randn(*self.weights.shape) * 0.1
            self.bias += np.random.randn() * 0.1

    def copy(self):
        copied = NeuronGenome(len(self.weights))
        copied.weights = np.copy(self.weights)
        copied.bias = self.bias
        return copied

    def __getstate__(self):
        return {'weights': self.weights, 'bias': self.bias}

    def __setstate__(self, state):
        self.weights = state['weights']
        self.bias = state['bias']

class HESPModule:
    def __init__(self, num_neurons, input_size):
        self.neurons = [NeuronGenome(input_size) for _ in range(num_neurons)]

    def forward(self, x):
        return [np.dot(n.weights, x) + n.bias for n in self.neurons]

    def copy(self):
        mod = HESPModule(0, 0)
        mod.neurons = [n.copy() for n in self.neurons]
        return mod

    def mutate(self):
        for neuron in self.neurons:
            neuron.mutate()

class HESPNetwork:
    def __init__(self, modules):
        self.modules = modules
        self.output_weights = np.random.randn(len(modules) * MODULE_SIZE, OUTPUT_SIZE)

    def forward(self, x):
        h = relu(np.concatenate([m.forward(x) for m in self.modules]))
        return softmax(np.dot(h, self.output_weights))

# ----------------------------- #
# 评估函数
# ----------------------------- #
def evaluate(network, env_name="LunarLander-v3"):
    env = gym.make(env_name)
    total_reward = 0
    for _ in range(EPISODES_PER_NETWORK):
        obs, _ = env.reset()
        done = False
        while not done:
            action_probs = network.forward(obs)
            action = np.argmax(action_probs)
            obs, reward, terminated, truncated, _ = env.step(action)
            done = terminated or truncated
            total_reward += reward
    env.close()
    return total_reward / EPISODES_PER_NETWORK

# ----------------------------- #
# H-ESP 主函数
# ----------------------------- #
def run_hesp():
    num_modules = HIDDEN_SIZE // MODULE_SIZE
    subpops = [[HESPModule(MODULE_SIZE, INPUT_SIZE) for _ in range(POP_SIZE)] for _ in range(num_modules)]
    output_weight_pool = [np.random.randn(HIDDEN_SIZE, OUTPUT_SIZE) for _ in range(POP_SIZE)]
    best_scores = []

    # 创建目录用于保存图像
    os.makedirs("charts", exist_ok=True)

    for gen in range(GENERATIONS):
        networks = []
        fitnesses = []

        for _ in range(POP_SIZE):
            indices = [random.randint(0, POP_SIZE-1) for _ in range(num_modules)]
            modules = [subpops[i][idx] for i, idx in enumerate(indices)]
            network = HESPNetwork(modules)
            network.output_weights = output_weight_pool[random.randint(0, POP_SIZE-1)]
            reward = evaluate(network)
            networks.append((network, indices))
            fitnesses.append(reward)

        usage = [[0]*POP_SIZE for _ in range(num_modules)]
        rewards = [[0.0]*POP_SIZE for _ in range(num_modules)]

        for idx, ((network, indices), reward) in enumerate(zip(networks, fitnesses)):
            for i, m_idx in enumerate(indices):
                usage[i][m_idx] += 1
                rewards[i][m_idx] += reward

        num_elites = int(POP_SIZE * ELITE_RATIO)
        for i in range(num_modules):
            avg_rewards = [rewards[i][j] / (usage[i][j] or 1) for j in range(POP_SIZE)]
            ranked = sorted(zip(avg_rewards, subpops[i]), key=lambda x: x[0], reverse=True)
            elites = [g.copy() for _, g in ranked[:num_elites]]
            next_pop = elites

            while len(next_pop) < POP_SIZE:
                parent = random.choice(elites)
                offspring = mutate_copy_module(parent)
                next_pop.append(offspring)

            subpops[i] = next_pop

        sorted_fitness = np.argsort(fitnesses)[::-1]
        elite_outputs = [output_weight_pool[i] for i in sorted_fitness[:num_elites]]

        next_outputs = []
        for w in elite_outputs:
            next_outputs.append(w.copy())

        for _ in range(POP_SIZE - num_elites):
            base = random.choice(elite_outputs)
            mutated = base + np.random.randn(*base.shape) * OUTPUT_MUTATION_STRENGTH
            next_outputs.append(mutated)

        output_weight_pool = next_outputs

        mean_score = np.mean(fitnesses)
        best_score = np.max(fitnesses)
        best_scores.append(mean_score)
        print(f"[H-ESP] Generation {gen}: avg reward = {mean_score:.2f}, best = {best_score:.2f}")

        # 保存每一代的图表
        if gen % (GENERATIONS // 10) == 0 or gen == GENERATIONS - 1:
            save_generation_chart(best_scores, gen)

    return subpops, output_weight_pool, best_scores

# ----------------------------- #
# 工具函数
# ----------------------------- #
def mutate_copy_neuron(neuron):
    new_neuron = neuron.copy()
    new_neuron.mutate()
    return new_neuron

def mutate_copy_module(module):
    new_module = module.copy()
    new_module.mutate()
    return new_module

def plot_module_structure(module, title="Module Structure"):
    G = nx.DiGraph()
    for i in range(INPUT_SIZE):
        G.add_node(f"Input{i}")
    neuron_nodes = [f"N{j}" for j in range(MODULE_SIZE)]
    for neuron in neuron_nodes:
        G.add_node(neuron)
    for i in range(INPUT_SIZE):
        for j in range(MODULE_SIZE):
            G.add_edge(f"Input{i}", f"N{j}")

    pos = nx.spring_layout(G, seed=42)
    plt.figure(figsize=(6, 4))
    nx.draw(G, pos, with_labels=True, node_size=800, node_color="lightblue", font_size=10, font_weight="bold")
    plt.title(title)
    plt.show()

def save_generation_chart(best_scores, gen):
    plt.plot(best_scores, label='Best Score')
    plt.xlabel("Generation")
    plt.ylabel("Average Reward")
    plt.title(f"Training Progress - Generation {gen}")
    filename = f"charts/gen_{gen}.png"
    plt.savefig(filename)
    plt.close()
    return filename

def create_training_gif(generations):
    images = []
    for gen in range(0, generations, max(1, generations // 10)):
        filename = f"charts/gen_{gen}.png"
        try:
            images.append(imageio.imread(filename))
        except FileNotFoundError:
            print(f"⚠️ File not found: {filename}")
    gif_filename = 'training_progress.gif'
    imageio.mimsave(gif_filename, images, duration=0.5)
    print("✅ GIF created at training_progress.gif")

def save_model(subpops, output_weights, filename="hesp_model.pkl"):
    with open(filename, 'wb') as f:
        pickle.dump((subpops, output_weights), f)

# ----------------------------- #
# 主程序入口
# ----------------------------- #
if __name__ == '__main__':
    subpops, output_weights, hesp_scores = run_hesp()
    save_model(subpops, output_weights)

    # 随机选取三个个体绘制模块结构图（避免越界）
    print("📊 Drawing module structures...")
    plot_module_structure(random.choice(subpops[0]), "Module Structure - Random Individual 1")
    plot_module_structure(random.choice(subpops[0]), "Module Structure - Random Individual 2")
    plot_module_structure(random.choice(subpops[0]), "Module Structure - Random Individual 3")

    # 创建 GIF
    print("🎞️ Creating training progress GIF...")
    create_training_gif(GENERATIONS)

    # 显示 GIF
    display(Image(data=open('training_progress.gif', 'rb').read()))
# Out:
# Collecting swig
#   Downloading swig-4.3.1-py3-none-manylinux_2_12_x86_64.manylinux2010_x86_64.whl.metadata (3.5 kB)
# Downloading swig-4.3.1-py3-none-manylinux_2_12_x86_64.manylinux2010_x86_64.whl (1.9 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.9/1.9 MB 16.6 MB/s eta 0:00:00
# Installing collected packages: swig
# Successfully installed swig-4.3.1
# Requirement already satisfied: gymnasium[box2d] in /usr/local/lib/python3.11/dist-packages (1.1.1)
# Requirement already satisfied: numpy>=1.21.0 in /usr/local/lib/python3.11/dist-packages (from gymnasium[box2d]) (2.0.2)
# Requirement already satisfied: cloudpickle>=1.2.0 in /usr/local/lib/python3.11/dist-packages (from gymnasium[box2d]) (3.1.1)
# Requirement already satisfied: typing-extensions>=4.3.0 in /usr/local/lib/python3.11/dist-packages (from gymnasium[box2d]) (4.14.0)
# Requirement already satisfied: farama-notifications>=0.0.1 in /usr/local/lib/python3.11/dist-packages (from gymnasium[box2d]) (0.0.4)
# Collecting box2d-py==2.3.5 (from gymnasium[box2d])
#   Downloading box2d-py-2.3.5.tar.gz (374 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 374.4/374.4 kB 6.7 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# Requirement already satisfied: pygame>=2.1.3 in /usr/local/lib/python3.11/dist-packages (from gymnasium[box2d]) (2.6.1)
# Requirement already satisfied: swig==4.* in /usr/local/lib/python3.11/dist-packages (from gymnasium[box2d]) (4.3.1)
# Building wheels for collected packages: box2d-py
#   Building wheel for box2d-py (setup.py) ... done
#   Created wheel for box2d-py: filename=box2d_py-2.3.5-cp311-cp311-linux_x86_64.whl size=2379376 sha256=ee3ec9c6b54ebd2354988487fb27cef06046b98d544490e5317a9298949b0e56
#   Stored in directory: /root/.cache/pip/wheels/ab/f1/0c/d56f4a2bdd12bae0a0693ec33f2f0daadb5eb9753c78fa5308
# Successfully built box2d-py
# Installing collected packages: box2d-py
# Successfully installed box2d-py-2.3.5
# Requirement already satisfied: matplotlib in /usr/local/lib/python3.11/dist-packages (3.10.0)
# Requirement already satisfied: networkx in /usr/local/lib/python3.11/dist-packages (3.5)
# Requirement already satisfied: imageio in /usr/local/lib/python3.11/dist-packages (2.37.0)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.11/dist-packages (from matplotlib) (1.3.2)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.11/dist-packages (from matplotlib) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.11/dist-packages (from matplotlib) (4.58.2)
# Requirement already satisfied: kiwisolver>=1.3.1 in /usr/local/lib/python3.11/dist-packages (from matplotlib) (1.4.8)
# Requirement already satisfied: numpy>=1.23 in /usr/local/lib/python3.11/dist-packages (from matplotlib) (2.0.2)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.11/dist-packages (from matplotlib) (24.2)
# Requirement already satisfied: pillow>=8 in /usr/local/lib/python3.11/dist-packages (from matplotlib) (11.2.1)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.11/dist-packages (from matplotlib) (3.2.3)
# Requirement already satisfied: python-dateutil>=2.7 in /usr/local/lib/python3.11/dist-packages (from matplotlib) (2.9.0.post0)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.11/dist-packages (from python-dateutil>=2.7->matplotlib) (1.17.0)
# [H-ESP] Generation 0: avg reward = -485.57, best = -133.26
# [H-ESP] Generation 1: avg reward = -420.71, best = -65.24
# [H-ESP] Generation 2: avg reward = -469.17, best = -121.35
# [H-ESP] Generation 3: avg reward = -481.47, best = -116.06
# [H-ESP] Generation 4: avg reward = -540.01, best = -184.41
# [H-ESP] Generation 5: avg reward = -370.21, best = -118.99
# [H-ESP] Generation 6: avg reward = -374.19, best = -129.78
# [H-ESP] Generation 7: avg reward = -222.78, best = -78.93
# [H-ESP] Generation 8: avg reward = -191.51, best = -95.79
# [H-ESP] Generation 9: avg reward = -146.69, best = -89.70
# [H-ESP] Generation 10: avg reward = -139.37, best = -99.94
# [H-ESP] Generation 11: avg reward = -132.99, best = -109.97
# [H-ESP] Generation 12: avg reward = -129.11, best = -102.99
# [H-ESP] Generation 13: avg reward = -126.95, best = -69.14
# [H-ESP] Generation 14: avg reward = -136.03, best = -98.53
# [H-ESP] Generation 15: avg reward = -123.97, best = -68.62
# [H-ESP] Generation 16: avg reward = -131.19, best = -87.13
# [H-ESP] Generation 17: avg reward = -138.50, best = -106.33
# [H-ESP] Generation 18: avg reward = -136.22, best = -105.50
# [H-ESP] Generation 19: avg reward = -128.29, best = -79.07
# [H-ESP] Generation 20: avg reward = -129.54, best = -78.87
# [H-ESP] Generation 21: avg reward = -128.29, best = -78.94
# [H-ESP] Generation 22: avg reward = -131.70, best = -86.66
# [H-ESP] Generation 23: avg reward = -132.62, best = -95.71
# [H-ESP] Generation 24: avg reward = -136.04, best = -95.91
# [H-ESP] Generation 25: avg reward = -135.60, best = -89.34
# [H-ESP] Generation 26: avg reward = -132.15, best = -90.30
# [H-ESP] Generation 27: avg reward = -127.35, best = -84.55
# [H-ESP] Generation 28: avg reward = -129.40, best = -103.62
# [H-ESP] Generation 29: avg reward = -131.23, best = -105.23
# [H-ESP] Generation 30: avg reward = -127.60, best = -69.00
# [H-ESP] Generation 31: avg reward = -130.74, best = -86.60
# [H-ESP] Generation 32: avg reward = -131.28, best = -96.95
# [H-ESP] Generation 33: avg reward = -128.00, best = -77.60
# [H-ESP] Generation 34: avg reward = -132.20, best = -94.64
# [H-ESP] Generation 35: avg reward = -132.00, best = -58.13
# [H-ESP] Generation 36: avg reward = -128.42, best = -66.88
# [H-ESP] Generation 37: avg reward = -130.49, best = -83.72
# [H-ESP] Generation 38: avg reward = -130.68, best = -98.49
# [H-ESP] Generation 39: avg reward = -126.47, best = -52.92
# [H-ESP] Generation 40: avg reward = -136.09, best = -99.87
# [H-ESP] Generation 41: avg reward = -130.61, best = -93.38
# [H-ESP] Generation 42: avg reward = -124.83, best = -84.94
# [H-ESP] Generation 43: avg reward = -132.26, best = -103.46
# [H-ESP] Generation 44: avg reward = -131.13, best = -84.77
# [H-ESP] Generation 45: avg reward = -127.46, best = -70.35
# [H-ESP] Generation 46: avg reward = -130.63, best = -90.52
# [H-ESP] Generation 47: avg reward = -133.47, best = -102.11
# [H-ESP] Generation 48: avg reward = -130.32, best = -81.05
# [H-ESP] Generation 49: avg reward = -131.15, best = -93.17
# [H-ESP] Generation 50: avg reward = -132.00, best = -104.96
# [H-ESP] Generation 51: avg reward = -134.26, best = -84.38
# [H-ESP] Generation 52: avg reward = -129.31, best = -90.71
# [H-ESP] Generation 53: avg reward = -130.37, best = -92.71
# [H-ESP] Generation 54: avg reward = -128.58, best = -93.41
# [H-ESP] Generation 55: avg reward = -130.96, best = -90.13
# [H-ESP] Generation 56: avg reward = -128.66, best = -93.26
# [H-ESP] Generation 57: avg reward = -130.60, best = -91.46
# [H-ESP] Generation 58: avg reward = -131.16, best = -91.26
# [H-ESP] Generation 59: avg reward = -131.57, best = -98.26
# [H-ESP] Generation 60: avg reward = -129.61, best = -97.52
# [H-ESP] Generation 61: avg reward = -140.04, best = -103.58
# [H-ESP] Generation 62: avg reward = -131.45, best = -92.14
# [H-ESP] Generation 63: avg reward = -128.87, best = -70.59
# [H-ESP] Generation 64: avg reward = -140.16, best = -121.08
# [H-ESP] Generation 65: avg reward = -132.09, best = -78.82
# [H-ESP] Generation 66: avg reward = -133.12, best = -93.68
# [H-ESP] Generation 67: avg reward = -135.26, best = -100.80
# [H-ESP] Generation 68: avg reward = -132.75, best = -78.83
# [H-ESP] Generation 69: avg reward = -135.40, best = -97.49
# [H-ESP] Generation 70: avg reward = -130.27, best = -96.05
# [H-ESP] Generation 71: avg reward = -130.22, best = -74.07
# [H-ESP] Generation 72: avg reward = -132.00, best = -100.83
# [H-ESP] Generation 73: avg reward = -134.27, best = -104.05
# [H-ESP] Generation 74: avg reward = -128.52, best = -98.93
# [H-ESP] Generation 75: avg reward = -135.60, best = -80.60
# [H-ESP] Generation 76: avg reward = -126.45, best = -92.95
# [H-ESP] Generation 77: avg reward = -140.08, best = -109.65
# [H-ESP] Generation 78: avg reward = -128.41, best = -54.67
# [H-ESP] Generation 79: avg reward = -136.57, best = -92.58
# [H-ESP] Generation 80: avg reward = -129.48, best = -94.05
# [H-ESP] Generation 81: avg reward = -131.85, best = -102.47
# [H-ESP] Generation 82: avg reward = -128.27, best = -87.79
# [H-ESP] Generation 83: avg reward = -121.20, best = -51.29
# [H-ESP] Generation 84: avg reward = -130.51, best = -93.39
# [H-ESP] Generation 85: avg reward = -132.07, best = -98.43
# [H-ESP] Generation 86: avg reward = -126.51, best = -96.42
# [H-ESP] Generation 87: avg reward = -126.05, best = -102.12
# [H-ESP] Generation 88: avg reward = -134.37, best = -75.55
# [H-ESP] Generation 89: avg reward = -129.94, best = -99.90
# [H-ESP] Generation 90: avg reward = -136.95, best = -97.93
# [H-ESP] Generation 91: avg reward = -131.49, best = -95.36
# [H-ESP] Generation 92: avg reward = -132.45, best = -97.81
# [H-ESP] Generation 93: avg reward = -135.76, best = -102.54
# [H-ESP] Generation 94: avg reward = -132.70, best = -100.63
# [H-ESP] Generation 95: avg reward = -131.30, best = -89.50
# [H-ESP] Generation 96: avg reward = -134.63, best = -102.86
# [H-ESP] Generation 97: avg reward = -126.28, best = -103.92
# [H-ESP] Generation 98: avg reward = -129.95, best = -88.10
# [H-ESP] Generation 99: avg reward = -133.81, best = -98.78
# [H-ESP] Generation 100: avg reward = -134.54, best = -89.81
# [H-ESP] Generation 101: avg reward = -133.71, best = -100.39
# [H-ESP] Generation 102: avg reward = -134.52, best = -87.31
# [H-ESP] Generation 103: avg reward = -133.49, best = -80.09
# [H-ESP] Generation 104: avg reward = -129.59, best = -74.47
# [H-ESP] Generation 105: avg reward = -131.99, best = -108.27
# [H-ESP] Generation 106: avg reward = -129.77, best = -79.42
# [H-ESP] Generation 107: avg reward = -130.38, best = -72.24
# [H-ESP] Generation 108: avg reward = -131.51, best = -84.49
# [H-ESP] Generation 109: avg reward = -128.68, best = -80.63
# [H-ESP] Generation 110: avg reward = -132.16, best = -91.03
# [H-ESP] Generation 111: avg reward = -136.09, best = -98.98
# [H-ESP] Generation 112: avg reward = -130.33, best = -70.56
# [H-ESP] Generation 113: avg reward = -136.45, best = -97.77
# [H-ESP] Generation 114: avg reward = -129.44, best = -97.84
# [H-ESP] Generation 115: avg reward = -131.66, best = -90.70
# [H-ESP] Generation 116: avg reward = -131.04, best = -85.53
# [H-ESP] Generation 117: avg reward = -134.80, best = -80.20
# [H-ESP] Generation 118: avg reward = -125.34, best = -64.06
# [H-ESP] Generation 119: avg reward = -132.91, best = -86.21
# [H-ESP] Generation 120: avg reward = -134.45, best = -96.49
# [H-ESP] Generation 121: avg reward = -132.06, best = -90.21
# [H-ESP] Generation 122: avg reward = -127.74, best = -79.85
# [H-ESP] Generation 123: avg reward = -130.18, best = -105.19
# [H-ESP] Generation 124: avg reward = -132.45, best = -103.84
# [H-ESP] Generation 125: avg reward = -127.65, best = -92.13
# [H-ESP] Generation 126: avg reward = -129.19, best = -84.52
# [H-ESP] Generation 127: avg reward = -134.53, best = -88.47
# [H-ESP] Generation 128: avg reward = -128.90, best = -64.42
# [H-ESP] Generation 129: avg reward = -139.32, best = -100.37
# [H-ESP] Generation 130: avg reward = -132.86, best = -97.53
# [H-ESP] Generation 131: avg reward = -133.79, best = -78.35
# [H-ESP] Generation 132: avg reward = -133.88, best = -103.94
# [H-ESP] Generation 133: avg reward = -125.91, best = -52.93
# [H-ESP] Generation 134: avg reward = -128.06, best = -69.37
# [H-ESP] Generation 135: avg reward = -130.27, best = -90.73
# [H-ESP] Generation 136: avg reward = -133.57, best = -85.36
# [H-ESP] Generation 137: avg reward = -133.57, best = -99.16
# [H-ESP] Generation 138: avg reward = -133.91, best = -99.71
# [H-ESP] Generation 139: avg reward = -130.83, best = -85.80
# [H-ESP] Generation 140: avg reward = -136.25, best = -56.29
# [H-ESP] Generation 141: avg reward = -133.41, best = -100.24
# [H-ESP] Generation 142: avg reward = -133.52, best = -70.20
# [H-ESP] Generation 143: avg reward = -130.45, best = -90.94
# [H-ESP] Generation 144: avg reward = -130.50, best = -79.45
# [H-ESP] Generation 145: avg reward = -131.36, best = -71.78
# [H-ESP] Generation 146: avg reward = -127.78, best = -90.16
# [H-ESP] Generation 147: avg reward = -128.51, best = -101.93
# [H-ESP] Generation 148: avg reward = -131.41, best = -60.23
# [H-ESP] Generation 149: avg reward = -136.37, best = -99.36
# 📊 Drawing module structures...
# 🎞️ Creating training progress GIF...
# ✅ GIF created at training_progress.gif
